# %% [markdown]
# # Double Deep Q Network
#
# ---
#
# Double DQN to solve OpenAI frogger environment

# %% [markdown]
# ### 1. Install necessary libraries and import packages
#
# ---

# %%
# !apt-get update
# !apt-get install xvfb
# !apt-get install x11-utils
# !apt-get install ffmpeg
# !apt-get install python-opengl
# !pip -q install gym pyvirtualdisplay pygame


# Environment
import gym # OpenAI gym
import frogger_env
gym.logger.set_level(40) # suppress warnings on gym

# Models and computation
import torch # will use pyTorch to handle NN
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from collections import deque
import random
from random import sample
from random import choices

# Visualization
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
from gym.wrappers import Monitor
import base64

# IO
from pathlib import Path
import os
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [577 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,163 kB]
# Hit:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,739 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,395 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [890 kB]
# Get:21 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [39.5 kB]
# Fetched 8,091 kB in 7s (1,144 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 31 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,270 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.8 [784 kB]
# Fetched 784 kB in 2s (378 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 160975 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.8_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.8) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.8) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libxxf86dga1
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   libxxf86dga1 x11-utils
# 0 upgraded, 2 newly installed, 0 to remove and 31 not upgraded.
# Need to get 209 kB of archives.
# After this operation, 711 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Fetched 209 kB in 2s (103 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 160982 files and directories currently installed.)
# Preparing to unpack .../libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl
# 0 upgraded, 1 newly installed, 0 to remove and 31 not upgraded.
# Need to get 496 kB of archives.
# After this operation, 5,416 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Fetched 496 kB in 2s (297 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 161036 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
#      |████████████████████████████████| 11.8MB 5.4MB/s

# %% [markdown]
# Let's define a simple helper function for visualization of episodes

# %% [markdown]
# # 2. Define the Q Network

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


# Simple NN with three hidden layers
class QNetwork(nn.Module):
    def __init__(self, s_size,  a_size, fc1_units, fc2_units, fc3_units):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(s_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, fc3_units)
        self.fc4 = nn.Linear(fc3_units, a_size)

    def forward(self, state):
        """Perform forward propagation."""

        x = state
        if not isinstance(x, torch.Tensor):
            x = torch.tensor(x,
                             device=device,
                             dtype=torch.float32)
            x = x.unsqueeze(0)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)

        return x

# %% [markdown]
# # 4. Double DQN Agent

# %%
class DDQNAgent():
    def __init__(self, state_size, action_size, batch_size, epochs, lr, eps, decay):
        """
        Initialize a Double DQNAgent object.

        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            batch_size (int):  minibatch size
            epochs (int):  training iterations
            lr (float): learning rate
            eps (float): exploration factor
            decay (float): exploration decay
        """
        self.state_size = state_size
        self.action_size = action_size
        self.batch_size = batch_size
        self.epochs = epochs
        self.lr = lr
        self.eps = eps
        self.decay = decay
        self.countst = 0

        # Q-Network and target network initialize
        self.qnetwork = QNetwork(state_size, action_size, 256, 128, 32).to(device)
        self.targetnet = QNetwork(state_size, action_size, 256, 128, 32).to(device)
        self.targetnet.load_state_dict(self.qnetwork.state_dict())
        # Optimizer
        self.optimizer = optim.RMSprop(self.qnetwork.parameters(), lr=self.lr)

    def learn(self, experiences, TAU):
        """
        Update q-network parameters using a batch of experience tuples.

        Params
        ======
        experiences (Tuple[torch.Tensor]): tuple of (s, a, r, s', done)
        tau (float): soft update interpolation parameter
        """
        states, actions, rewards, next_states, dones = experiences
        batch_size = len(dones)

        ################ Begin Modification for Double DQN#####################
        # Get max Q values for next states from local qnetwork net
        q_next_action = self.qnetwork(next_states).detach()
        q_max_next_action = torch.argmax(q_next_action, dim = 1).unsqueeze(1)
        doublqq_states = self.targetnet(next_states).gather(1, q_max_next_action)
        # Compute Q targets for current states
        q_targets = rewards + (self.gamma * doublqq_states * (1 - dones))
        ################ End Modification for Double DQN#####################

        # Get predicted Q values
        q_predicted = self.qnetwork(states).gather(1, actions)

        # Compute loss
        loss = F.mse_loss(q_predicted, q_targets)
        #td_errors = q_predicted - q_targerts
        #loss = td_errors.pow(2).mul(0.5).mean() #equivalent

        # Minimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # use soft update
        self.soft_update(self.qnetwork, self.targetnet, TAU)

    def soft_update(self, local_model, target_model, tau):
        """
        Soft update model parameters

        Params
        ======
            local_model (ptorch model): weights copied from
            target_model (pytorch model): weight copied to
            tau (float): interpolation parameter
        """
        #### soft update model parameters ######
        # target = tau * local + (1 - tau) * target
        # soft max update algorith from below link
        # https://medium.com/@unnatsingh/deep-q-network-with-pytorch-d1ca6f40bfda
        for target_param,local_param in zip(target_model.parameters(),local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

    def epsilon_greedy_action(self, state):
        """
        Returns action for given state.

        Params
        ======
            state (array_like): current state
            eps (float): epsilon
        """
        with torch.no_grad():
            q_values = self.qnetwork(state).cpu().detach().data.numpy().squeeze()

        if np.random.rand() > self.eps:
            action = np.argmax(q_values)
        else:
            action = np.random.randint(len(q_values))

        return action

    def greedy_action(self, state):
        """
        Returns the greedy action.

        Params
        ======
            state (array_like): current state
        """
        with torch.no_grad():
            q_values = self.qnetwork(state).cpu().detach().data.numpy().squeeze()
        return np.argmax(q_values)

    def collect_experience(self, env, state):
        """
        Collect an experience and add it to the experiences dataset.
        Returns the new state and whether it is terminal.

        Params
        ======
            env: the environment
            state (array_like): current state
            eps (float): epsilon
        """
        action = self.epsilon_greedy_action(state)
        new_state, reward, is_terminal, info = env.step(action)
        is_truncated = 'TimeLimit.truncated' in info and info['TimeLimit.truncated']
        is_failure = is_terminal and not is_truncated
        experience = (state, action, reward, new_state, float(is_failure))
        self.experiences.append(experience)

        self.episode_reward[-1] += reward
        self.episode_timestep[-1] += 1
        self.countst += 1
#       Linear decay of eps. Eps stays 1.0 for the first 10% of steps. This is to encourage exploration
#        if self.countst > (max_steps/10) and self.eps > 0.2:
        if self.eps > 0.01:
            self.eps -= self.decay

        return new_state, is_terminal

    def evaluate(self, env, n_rollouts=1):
        """
        Returns the mean + std score obtained by executing the greedy policy for a fixed number of rollouts.

        Params
        ======
            env: the environment
            n_rollouts (int): the number of rollouts to be performed
        """
        rewards = []
        for _ in range(n_rollouts):
            state, done = env.reset(), False
            rewards.append(0)
            while not done:
                action = self.greedy_action(state)
                state, reward, done, _ = env.step(action)
                rewards[-1] += reward
        return np.mean(rewards), np.std(rewards)

    def train(self, env, seed, gamma, max_episodes, max_steps, goal_mean_100_reward, TAU):
        """
        Training the agent.
        Returns a list of (total number steps, average training reward over last 100 episodes,
                           average evaluation reward over last 100 episodes) per episode

        Params
        ======
            env: open ai environment
            seed (int): a random of fixed seed number
            gamma (float): the discount factor
            max_episodes (int): total number of episodes
            max_steps (int): total number of allowed steps
            goal_mean_100_reward: the threshold, as measured by average evaluation reward over 100 episodes,
                                  denoting whether the problem is solved
            tau (float): soft update interpolation parameter
        """

        self.seed = seed
        self.gamma = gamma
        torch.manual_seed(self.seed)
        np.random.seed(self.seed)

        self.episode_reward = []
        self.evaluation_scores = []
        self.experiences = deque(maxlen=30000)    #replay buffer
        self.episode_timestep = []
        self.noexp = 0

        mean_100_eval_score = 0.0

        # store the total steps, the mean reward over the last 100 steps,
        # and the mean evaluation reward over the last 100 episodes
        result = np.empty((max_episodes, 3))
        result[:] = np.nan
#        eps = 1.0
        for episode in range(1, max_episodes + 1):

            state, is_terminal = env.reset(), False
            self.episode_reward.append(0.0)
            self.episode_timestep.append(0.0)

            while True:
                state, is_terminal = self.collect_experience(env, state)
                self.noexp += 1


                if len(self.experiences) >= self.batch_size:
                    #experiences = np.array(self.experiences)
                    experiences = np.array(choices(self.experiences, k=self.batch_size))


                    batches = [np.vstack(e) for e in experiences.T]
                    states, actions, rewards, new_states, is_terminals = batches

                    # load the dataset to the device
                    states = torch.from_numpy(states).float().to(device)
                    actions = torch.from_numpy(actions).long().to(device)
                    new_states = torch.from_numpy(new_states).float().to(device)
                    rewards = torch.from_numpy(rewards).float().to(device)
                    is_terminals = torch.from_numpy(is_terminals).float().to(device)
                    experiences = (states, actions, rewards, new_states, is_terminals)

                    for _ in range(self.epochs):
                        self.learn(experiences, TAU)
#                    self.experiences.clear()

                # if (self.noexp%400) == 0:
                #     self.targetnet.load_state_dict(self.qnetwork.state_dict())

                if is_terminal:
                    break

            # bookkeeping
            evaluation_score, _ = self.evaluate(env) # evaluate using the greedy policy

            total_steps = int(np.sum(self.episode_timestep)) # total number of environment steps
            self.evaluation_scores.append(evaluation_score)

            mean_100_reward = np.mean(self.episode_reward[-100:])
            std_100_reward = np.std(self.episode_reward[-100:])
            mean_100_eval_score = np.mean(self.evaluation_scores[-100:])
            std_100_eval_score = np.std(self.evaluation_scores[-100:])

            result[episode-1] = total_steps, mean_100_reward, mean_100_eval_score
#            print(self.eps)

            print('Episode: {:d}, Total Steps: {:d}, Train_reward: {:.2f}, Eval_reward: {:.2f}'.format(episode-1,total_steps,\
                  mean_100_reward, mean_100_eval_score))

            # the problem considered solved if the average score over 100 consecutive trials is above
            #goal_mean_100_reward
            training_is_over = mean_100_eval_score >= goal_mean_100_reward or \
                               total_steps >= max_steps
            if training_is_over:
                if total_steps >= max_steps: print('--> reached_max_steps')
                if mean_100_eval_score >= goal_mean_100_reward:
                    print('Environment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode-1, mean_100_eval_score))
                break

        save_checkpoint(self.qnetwork,'q2_domini4_'+str(seed)+'.pt',1)
        return result

# %%
from google.colab import drive
from google.colab import files

def save_checkpoint(model, filename, mode=0):
    """
    Save a model to a file in your colab space

    Parameters
    ----------
    model: your Q network
    filename: the name of the checkpoint file
    mode (int): determines where to store the file
                --> 0: collab space 1: Google Drive
    """
    if mode == 1:
      drive.mount('/content/gdrive')
      path = F"/content/gdrive/My Drive/{filename}"
      torch.save(model.state_dict(), path)
    else:
      torch.save(model.state_dict(), filename)

def export_to_local_drive(filename):
    """
    Download a file to your local machine

    Parameters
    ----------
    filename: the name of the file
    """
    files.download(filename)

# %% [markdown]
# # 4. Train with Double DQN

# %%
env = gym.make('frogger-v1')
batch_size = 64
epochs = 3
lr = 1e-4
gamma = 0.9
TAU = 1e-2
max_episodes = 10000
max_steps = 30000
eps = 1.0
decay = eps/max_steps
#goal_mean_100_reward = env.spec.reward_threshold
goal_mean_100_reward = 1.3

# seed = 8
# env.seed(seed)
# agentd1 = DDQNAgent(env.observation_space.shape[0], env.action_space.n, batch_size, epochs, lr, eps, decay)
# resultd1 = agentd1.train(env, seed, gamma, max_episodes, max_steps, goal_mean_100_reward, TAU)
#env.close()

seed = 10
env.seed(seed)
agentd2 = DDQNAgent(env.observation_space.shape[0], env.action_space.n, batch_size, epochs, lr, eps, decay)
resultd2 = agentd2.train(env, seed, gamma, max_episodes, max_steps, goal_mean_100_reward, TAU)
env.close()

# seed = 12
# env.seed(seed)
# agentd3 = DDQNAgent(env.observation_space.shape[0], env.action_space.n, batch_size, epochs, lr, eps, decay)
# resultd3 = agentd3.train(env, seed, gamma, max_episodes, max_steps, goal_mean_100_reward, TAU)
# env.close()


del env
# Out:
# Episode: 0, Total Steps: 39, Train_reward: -0.26, Eval_reward: -0.03
# Episode: 1, Total Steps: 49, Train_reward: -0.27, Eval_reward: -0.03
# Episode: 2, Total Steps: 55, Train_reward: -0.19, Eval_reward: -0.03
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:198: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# Episode: 3, Total Steps: 74, Train_reward: -0.15, Eval_reward: -0.13
# Episode: 4, Total Steps: 97, Train_reward: -0.17, Eval_reward: -0.16
# Episode: 5, Total Steps: 102, Train_reward: -0.19, Eval_reward: -0.18
# Episode: 6, Total Steps: 142, Train_reward: -0.20, Eval_reward: -0.19
# Episode: 7, Total Steps: 204, Train_reward: -0.18, Eval_reward: -0.20
# Episode: 8, Total Steps: 221, Train_reward: -0.16, Eval_reward: -0.21
# Episode: 9, Total Steps: 237, Train_reward: -0.17, Eval_reward: -0.21
# Episode: 10, Total Steps: 264, Train_reward: -0.18, Eval_reward: -0.21
# Episode: 11, Total Steps: 285, Train_reward: -0.19, Eval_reward: -0.22
# Episode: 12, Total Steps: 331, Train_reward: -0.18, Eval_reward: -0.22
# Episode: 13, Total Steps: 374, Train_reward: -0.18, Eval_reward: -0.23
# Episode: 14, Total Steps: 380, Train_reward: -0.19, Eval_reward: -0.23
# Episode: 15, Total Steps: 388, Train_reward: -0.18, Eval_reward: -0.23
# Episode: 16, Total Steps: 400, Train_reward: -0.17, Eval_reward: -0.23
# Episode: 17, Total Steps: 405, Train_reward: -0.17, Eval_reward: -0.26
# Episode: 18, Total Steps: 415, Train_reward: -0.18, Eval_reward: -0.27
# Episode: 19, Total Steps: 446, Train_reward: -0.17, Eval_reward: -0.27
# Episode: 20, Total Steps: 486, Train_reward: -0.17, Eval_reward: -0.27
# Episode: 21, Total Steps: 536, Train_reward: -0.17, Eval_reward: -0.28
# Episode: 22, Total Steps: 541, Train_reward: -0.16, Eval_reward: -0.27
# Episode: 23, Total Steps: 548, Train_reward: -0.16, Eval_reward: -0.27
# Episode: 24, Total Steps: 573, Train_reward: -0.15, Eval_reward: -0.27
# Episode: 25, Total Steps: 612, Train_reward: -0.15, Eval_reward: -0.27
# Episode: 26, Total Steps: 693, Train_reward: -0.15, Eval_reward: -0.27
# Episode: 27, Total Steps: 798, Train_reward: -0.15, Eval_reward: -0.27
# Episode: 28, Total Steps: 827, Train_reward: -0.14, Eval_reward: -0.27
# Episode: 29, Total Steps: 842, Train_reward: -0.15, Eval_reward: -0.27
# Episode: 30, Total Steps: 878, Train_reward: -0.15, Eval_reward: -0.27
# Episode:
Train_reward: -0.26, Eval_reward: 0.04
# Episode: 380, Total Steps: 10334, Train_reward: -0.26, Eval_reward: 0.04
# Episode: 381, Total Steps: 10340, Train_reward: -0.26, Eval_reward: 0.04
# Episode: 382, Total Steps: 10367, Train_reward: -0.26, Eval_reward: 0.04
# Episode: 383, Total Steps: 10447, Train_reward: -0.26, Eval_reward: 0.04
# Episode: 384, Total Steps: 10540, Train_reward: -0.26, Eval_reward: 0.03
# Episode: 385, Total Steps: 10553, Train_reward: -0.26, Eval_reward: 0.03
# Episode: 386, Total Steps: 10601, Train_reward: -0.26, Eval_reward: 0.03
# Episode: 387, Total Steps: 10629, Train_reward: -0.26, Eval_reward: 0.04
# Episode: 388, Total Steps: 10659, Train_reward: -0.26, Eval_reward: 0.04
# Episode: 389, Total Steps: 10673, Train_reward: -0.26, Eval_reward: 0.05
# Episode: 390, Total Steps: 10687, Train_reward: -0.26, Eval_reward: 0.05
# Episode: 391, Total Steps: 10712, Train_reward: -0.26, Eval_reward: 0.06
# Episode: 392, Total Steps: 10743, Train_reward: -0.25, Eval_reward: 0.06
# Episode: 393, Total Steps: 10753, Train_reward: -0.25, Eval_reward: 0.06
# Episode: 394, Total Steps: 10791, Train_reward: -0.25, Eval_reward: 0.06
# Episode: 395, Total Steps: 10808, Train_reward: -0.25, Eval_reward: 0.06
# Episode: 396, Total Steps: 10842, Train_reward: -0.25, Eval_reward: 0.08
# Episode: 397, Total Steps: 10848, Train_reward: -0.25, Eval_reward: 0.07
# Episode: 398, Total Steps: 10874, Train_reward: -0.25, Eval_reward: 0.09
# Episode: 399, Total Steps: 10879, Train_reward: -0.25, Eval_reward: 0.10
# Episode: 400, Total Steps: 10906, Train_reward: -0.25, Eval_reward: 0.10
# Episode: 401, Total Steps: 10916, Train_reward: -0.25, Eval_reward: 0.12
# Episode: 402, Total Steps: 10924, Train_reward: -0.25, Eval_reward: 0.12
# Episode: 403, Total Steps: 10937, Train_reward: -0.25, Eval_reward: 0.12
# Episode: 404, Total Steps: 10980, Train_reward: -0.25, Eval_reward: 0.12
# Episode: 405, Total Steps: 10995, Train_reward: -0.25, Eval_reward: 0.12
# Episode: 406, Total Steps: 11039, Train_reward: -0.26, Eval_reward: 0.12
# Episode: 407, Total Steps: 11047, Train_reward: -0.26, Eval_reward: 0.13
# Episode: 408, Total Steps: 11087, Train_reward: -0.25, Eval_reward: 0.13
# Episode: 409, Total Steps: 11103, Train_reward: -0.26, Eval_reward: 0.13
# Episode: 410, Total Steps: 11116, Train_reward: -0.26, Eval_reward: 0.13
# Episode: 411, Total Steps: 11131, Train_reward: -0.26, Eval_reward: 0.13
# Episode: 412, Total Steps: 11154, Train_reward: -0.26, Eval_reward: 0.13
# Episode: 413, Total Steps: 11177, Train_reward: -0.26, Eval_reward: 0.15
# Episode: 414, Total Steps: 11198, Train_reward: -0.26, Eval_reward: 0.16
# Episode: 415, Total Steps: 11212, Train_reward: -0.26, Eval_reward: 0.17
# Episode: 416, Total Steps: 11235, Train_reward: -0.25, Eval_reward: 0.17
# Episode: 417, Total Steps: 11249, Train_reward: -0.26, Eval_reward: 0.17
# Episode: 418, Total Steps: 11292, Train_reward: -0.25, Eval_reward: 0.17
# Episode: 419, Total Steps: 11300, Train_reward: -0.25, Eval_reward: 0.17
# Episode: 420, Total Steps: 11361, Train_reward: -0.25, Eval_reward: 0.19
# Episode: 421, Total Steps: 11381, Train_reward: -0.25, Eval_reward: 0.18
# Episode: 422, Total Steps: 11396, Train_reward: -0.26, Eval_reward: 0.17
# Episode: 423, Total Steps: 11410, Train_reward: -0.25, Eval_reward: 0.17
# Episode: 424, Total Steps: 11475, Train_reward: -0.25, Eval_reward: 0.19
# Episode: 425, Total Steps: 11496, Train_reward: -0.25, Eval_reward: 0.19
# Episode: 426, Total Steps: 11537, Train_reward: -0.25, Eval_reward: 0.19
# Episode: 427, Total Steps: 11552, Train_reward: -0.25, Eval_reward: 0.19
# Episode: 428, Total Steps: 11570, Train_reward: -0.25, Eval_reward: 0.19
# Episode: 429, Total Steps: 11581, Train_reward: -0.25, Eval_reward: 0.17
# Episode:
# Episode: 855, Total Steps: 23194, Train_reward: -0.12, Eval_reward: 0.69
# Episode: 856, Total Steps: 23231, Train_reward: -0.12, Eval_reward: 0.71
# Episode: 857, Total Steps: 23241, Train_reward: -0.12, Eval_reward: 0.71
# Episode: 858, Total Steps: 23252, Train_reward: -0.12, Eval_reward: 0.71
# Episode: 859, Total Steps: 23312, Train_reward: -0.12, Eval_reward: 0.72
# Episode: 860, Total Steps: 23323, Train_reward: -0.12, Eval_reward: 0.72
# Episode: 861, Total Steps: 23372, Train_reward: -0.12, Eval_reward: 0.74
# Episode: 862, Total Steps: 23473, Train_reward: -0.12, Eval_reward: 0.74
# Episode: 863, Total Steps: 23549, Train_reward: -0.12, Eval_reward: 0.75
# Episode: 864, Total Steps: 23623, Train_reward: -0.10, Eval_reward: 0.75
# Episode: 865, Total Steps: 23667, Train_reward: -0.10, Eval_reward: 0.75
# Episode: 866, Total Steps: 23680, Train_reward: -0.10, Eval_reward: 0.75
# Episode: 867, Total Steps: 23719, Train_reward: -0.10, Eval_reward: 0.75
# Episode: 868, Total Steps: 23761, Train_reward: -0.10, Eval_reward: 0.75
# Episode: 869, Total Steps: 23850, Train_reward: -0.09, Eval_reward: 0.75
# Episode: 870, Total Steps: 23891, Train_reward: -0.10, Eval_reward: 0.77
# Episode: 871, Total Steps: 23903, Train_reward: -0.10, Eval_reward: 0.77
# Episode: 872, Total Steps: 23952, Train_reward: -0.10, Eval_reward: 0.78
# Episode: 873, Total Steps: 23955, Train_reward: -0.12, Eval_reward: 0.78
# Episode: 874, Total Steps: 24022, Train_reward: -0.12, Eval_reward: 0.78
# Episode: 875, Total Steps: 24083, Train_reward: -0.10, Eval_reward: 0.78
# Episode: 876, Total Steps: 24100, Train_reward: -0.10, Eval_reward: 0.78
# Episode: 877, Total Steps: 24115, Train_reward: -0.10, Eval_reward: 0.77
# Episode: 878, Total Steps: 24165, Train_reward: -0.10, Eval_reward: 0.77
# Episode: 879, Total Steps: 24216, Train_reward: -0.09, Eval_reward: 0.78
# Episode: 880, Total Steps: 24244, Train_reward: -0.09, Eval_reward: 0.77
# Episode: 881, Total Steps: 24282, Train_reward: -0.09, Eval_reward: 0.77
# Episode: 882, Total Steps: 24305, Train_reward: -0.08, Eval_reward: 0.76
# Episode: 883, Total Steps: 24354, Train_reward: -0.08, Eval_reward: 0.76
# Episode: 884, Total Steps: 24391, Train_reward: -0.07, Eval_reward: 0.76
# Episode: 885, Total Steps: 24438, Train_reward: -0.07, Eval_reward: 0.76
# Episode: 886, Total Steps: 24468, Train_reward: -0.07, Eval_reward: 0.76
# Episode: 887, Total Steps: 24500, Train_reward: -0.07, Eval_reward: 0.77
# Episode: 888, Total Steps: 24556, Train_reward: -0.05, Eval_reward: 0.77
# Episode: 889, Total Steps: 24610, Train_reward: -0.04, Eval_reward: 0.78
# Episode: 890, Total Steps: 24668, Train_reward: -0.02, Eval_reward: 0.78
# Episode: 891, Total Steps: 24728, Train_reward: -0.02, Eval_reward: 0.78
# Episode: 892, Total Steps: 24760, Train_reward: -0.02, Eval_reward: 0.77
# Episode: 893, Total Steps: 24768, Train_reward: -0.02, Eval_reward: 0.77
# Episode: 894, Total Steps: 24823, Train_reward: -0.01, Eval_reward: 0.78
# Episode: 895, Total Steps: 24890, Train_reward: 0.01, Eval_reward: 0.78
# Episode: 896, Total Steps: 24938, Train_reward: 0.02, Eval_reward: 0.78
# Episode: 897, Total Steps: 25001, Train_reward: 0.02, Eval_reward: 0.80
# Episode: 898, Total Steps: 25035, Train_reward: 0.01, Eval_reward: 0.78
# Episode: 899, Total Steps: 25045, Train_reward: 0.01, Eval_reward: 0.76
# Episode: 900, Total Steps: 25055, Train_reward: 0.00, Eval_reward: 0.77
# Episode: 901, Total Steps: 25084, Train_reward: 0.00, Eval_reward: 0.76
# Episode: 902, Total Steps: 25096, Train_reward: 0.00, Eval_reward: 0.76
# Episode: 903, Total Steps: 25139, Train_reward: 0.00, Eval_reward: 0.76
# Episode: 904, Total Steps: 25174, Train_reward: 0.00, Eval_reward: 0.76
# Episode: 905, Total Steps: 25184, Train_reward: 0.00, Eval_reward: 0.76
# Episode: 906, Total Steps: 25198, Train_reward: 0.00, Eval_reward: 0.76
# Episode: 907, Total Steps: 25239, Train_reward: 0.01, Eval_reward: 0.76
# Episode: 908, Total Steps: 25327, Train_reward: 0.02, Eval_reward: 0.77
# Episode: 909, Total Steps: 25373, Train_reward: 0.02, Eval_reward: 0.77
# Episode: 910, Total Steps: 25441, Train_reward: 0.02, Eval_reward: 0.76
# Episode: 911, Total Steps: 25449, Train_reward: 0.02, Eval_reward: 0.76
# Episode: 912, Total Steps: 25480, Train_reward: 0.02, Eval_reward: 0.77
# Episode: 913, Total Steps: 25497, Train_reward: 0.02, Eval_reward: 0.77
# Episode: 914, Total Steps: 25539, Train_reward: 0.04, Eval_reward: 0.78
# Episode: 915, Total Steps: 25548, Train_reward: 0.04, Eval_reward: 0.78
# Episode: 916, Total Steps: 25606, Train_reward: 0.05, Eval_reward: 0.78
# Episode: 917, Total Steps: 25651, Train_reward: 0.05, Eval_reward: 0.77
# Episode: 918, Total Steps: 25680, Train_reward: 0.05, Eval_reward: 0.75
# Episode: 919, Total Steps: 25737, Train_reward: 0.05, Eval_reward: 0.74
# Episode: 920, Total Steps: 25752, Train_reward: 0.05, Eval_reward: 0.74
# Episode: 921, Total Steps: 25798, Train_reward: 0.07, Eval_reward: 0.74
# Episode: 922, Total Steps: 25815, Train_reward: 0.07, Eval_reward: 0.74
# Episode: 923, Total Steps: 25827, Train_reward: 0.07, Eval_reward: 0.72
# Episode: 924, Total Steps: 25868, Train_reward: 0.07, Eval_reward: 0.72
# Episode: 925, Total Steps: 25912, Train_reward: 0.08, Eval_reward: 0.74
# Episode: 926, Total Steps: 25981, Train_reward: 0.08, Eval_reward: 0.74
# Episode: 927, Total Steps: 26020, Train_reward: 0.10, Eval_reward: 0.74
# Episode: 928, Total Steps: 26067, Train_reward: 0.11, Eval_reward: 0.74
# Episode: 929, Total Steps: 26099, Train_reward: 0.11, Eval_reward: 0.75
# Episode: 930, Total Steps: 26145, Train_reward: 0.13, Eval_reward: 0.74
# Episode: 931, Total Steps: 26199, Train_reward: 0.14, Eval_reward: 0.76
# Episode: 932, Total Steps: 26233, Train_reward: 0.14, Eval_reward: 0.76
# Episode: 933, Total Steps: 26277, Train_reward: 0.16, Eval_reward: 0.77
# Episode: 934, Total Steps: 26314, Train_reward: 0.16, Eval_reward: 0.77
# Episode: 935, Total Steps: 26355, Train_reward: 0.17, Eval_reward: 0.77
# Episode: 936, Total Steps: 26387, Train_reward: 0.17, Eval_reward: 0.77
# Episode: 937, Total Steps: 26410, Train_reward: 0.16, Eval_reward: 0.75
# Episode: 938, Total Steps: 26483, Train_reward: 0.16, Eval_reward: 0.77
# Episode: 939, Total Steps: 26523, Train_reward: 0.17, Eval_reward: 0.78
# Episode: 940, Total Steps: 26581, Train_reward: 0.17, Eval_reward: 0.79
# Episode: 941, Total Steps: 26601, Train_reward: 0.17, Eval_reward: 0.79
# Episode: 942, Total Steps: 26667, Train_reward: 0.18, Eval_reward: 0.79
# Episode: 943, Total Steps: 26713, Train_reward: 0.20, Eval_reward: 0.78
# Episode: 944, Total Steps: 26798, Train_reward: 0.20, Eval_reward: 0.77
# Episode: 945, Total Steps: 26870, Train_reward: 0.19, Eval_reward: 0.77
# Episode: 946, Total Steps: 26906, Train_reward: 0.19, Eval_reward: 0.75
# Episode: 947, Total Steps: 26951, Train_reward: 0.20, Eval_reward: 0.75
# Episode: 948, Total Steps: 27000, Train_reward: 0.20, Eval_reward: 0.75
# Episode: 949, Total Steps: 27015, Train_reward: 0.19, Eval_reward: 0.77
# Episode: 950, Total Steps: 27064, Train_reward: 0.20, Eval_reward: 0.77
# Episode: 951, Total Steps: 27082, Train_reward: 0.20, Eval_reward: 0.77
# Episode: 952, Total Steps: 27099, Train_reward: 0.20, Eval_reward: 0.77
# Episode: 953, Total Steps: 27164, Train_reward: 0.20, Eval_reward: 0.77
# Episode: 954, Total Steps: 27169, Train_reward: 0.20, Eval_reward: 0.78
# Episode: 955, Total Steps: 27175, Train_reward: 0.20, Eval_reward: 0.79
# Episode: 956, Total Steps: 27196, Train_reward: 0.20, Eval_reward: 0.79
# Episode: 957, Total Steps: 27263, Train_reward: 0.21, Eval_reward: 0.81
# Episode: 958, Total Steps: 27302, Train_reward: 0.22, Eval_reward: 0.81
# Episode: 959, Total Steps: 27335, Train_reward: 0.22, Eval_reward: 0.81
# Episode: 960, Total Steps: 27370, Train_reward: 0.23, Eval_reward: 0.80
# Episode: 961, Total Steps: 27438, Train_reward: 0.25, Eval_reward: 0.80
# Episode: 962, Total Steps: 27485, Train_reward: 0.26, Eval_reward: 0.80
# Episode: 963, Total Steps: 27495, Train_reward: 0.26, Eval_reward: 0.80
# Episode: 964, Total Steps: 27551, Train_reward: 0.26, Eval_reward: 0.81
# Episode: 965, Total Steps: 27581, Train_reward: 0.26, Eval_reward: 0.83
# Episode: 966, Total Steps: 27620, Train_reward: 0.27, Eval_reward: 0.83
# Episode: 967, Total Steps: 27666, Train_reward: 0.27, Eval_reward: 0.83
# Episode: 968, Total Steps: 27707, Train_reward: 0.29, Eval_reward: 0.81
# Episode: 969, Total Steps: 27770, Train_reward: 0.29, Eval_reward: 0.80
# Episode: 970, Total Steps: 27815, Train_reward: 0.30, Eval_reward: 0.80
# Episode: 971, Total Steps: 27856, Train_reward: 0.31, Eval_reward: 0.81
# Episode: 972, Total Steps: 27899, Train_reward: 0.33, Eval_reward: 0.81
# Episode: 973, Total Steps: 27955, Train_reward: 0.33, Eval_reward: 0.82
# Episode: 974, Total Steps: 27988, Train_reward: 0.34, Eval_reward: 0.82
# Episode: 975, Total Steps: 28029, Train_reward: 0.34, Eval_reward: 0.82
# Episode: 976, Total Steps: 28068, Train_reward: 0.36, Eval_reward: 0.82
# Episode: 977, Total Steps: 28091, Train_reward: 0.36, Eval_reward: 0.84
# Episode: 978, Total Steps: 28119, Train_reward: 0.36, Eval_reward: 0.82
# Episode: 979, Total Steps: 28180, Train_reward: 0.36, Eval_reward: 0.82
# Episode: 980, Total Steps: 28232, Train_reward: 0.37, Eval_reward: 0.84
# Episode: 981, Total Steps: 28249, Train_reward: 0.37, Eval_reward: 0.84
# Episode: 982, Total Steps: 28305, Train_reward: 0.39, Eval_reward: 0.84
# Episode: 983, Total Steps: 28335, Train_reward: 0.40, Eval_reward: 0.84
# Episode: 984, Total Steps: 28390, Train_reward: 0.40, Eval_reward: 0.85
# Episode: 985, Total Steps: 28424, Train_reward: 0.40, Eval_reward: 0.86
# Episode: 986, Total Steps: 28491, Train_reward: 0.42, Eval_reward: 0.85
# Episode: 987, Total Steps: 28535, Train_reward: 0.42, Eval_reward: 0.84
# Episode: 988, Total Steps: 28551, Train_reward: 0.40, Eval_reward: 0.84
# Episode: 989, Total Steps: 28564, Train_reward: 0.39, Eval_reward: 0.84
# Episode: 990, Total Steps: 28628, Train_reward: 0.39, Eval_reward: 0.84
# Episode: 991, Total Steps: 28667, Train_reward: 0.39, Eval_reward: 0.85
# Episode: 992, Total Steps: 28723, Train_reward: 0.39, Eval_reward: 0.85
# Episode: 993, Total Steps: 28751, Train_reward: 0.39, Eval_reward: 0.85
# Episode: 994, Total Steps: 28793, Train_reward: 0.39, Eval_reward: 0.85
# Episode: 995, Total Steps: 28839, Train_reward: 0.39, Eval_reward: 0.84
# Episode: 996, Total Steps: 28872, Train_reward: 0.38, Eval_reward: 0.84
# Episode: 997, Total Steps: 28910, Train_reward: 0.38, Eval_reward: 0.84
# Episode: 998, Total Steps: 28944, Train_reward: 0.39, Eval_reward: 0.84
# Episode: 999, Total Steps: 28983, Train_reward: 0.41, Eval_reward: 0.85
# Episode: 1000, Total Steps: 29029, Train_reward: 0.42, Eval_reward: 0.85
# Episode: 1001, Total Steps: 29082, Train_reward: 0.44, Eval_reward: 0.87
# Episode: 1002, Total Steps: 29203, Train_reward: 0.44, Eval_reward: 0.87
# Episode: 1003, Total Steps: 29238, Train_reward: 0.45, Eval_reward: 0.87
# Episode: 1004, Total Steps: 29265, Train_reward: 0.46, Eval_reward: 0.87
# Episode: 1005, Total Steps: 29291, Train_reward: 0.46, Eval_reward: 0.87
# Episode: 1006, Total Steps: 29412, Train_reward: 0.46, Eval_reward: 0.87
# Episode: 1007, Total Steps: 29467, Train_reward: 0.47, Eval_reward: 0.87
# Episode: 1008, Total Steps: 29509, Train_reward: 0.47, Eval_reward: 0.87
# Episode: 1009, Total Steps: 29567, Train_reward: 0.49, Eval_reward: 0.87
# Episode: 1010, Total Steps: 29607, Train_reward: 0.50, Eval_reward: 0.87
# Episode: 1011, Total Steps: 29646, Train_reward: 0.52, Eval_reward: 0.87
# Episode: 1012, Total Steps: 29704, Train_reward: 0.53, Eval_reward: 0.87
# Episode: 1013, Total Steps: 29742, Train_reward: 0.55, Eval_reward: 0.87
# Episode: 1014, Total Steps: 29796, Train_reward: 0.55, Eval_reward: 0.86
# Episode: 1015, Total Steps: 29860, Train_reward: 0.56, Eval_reward: 0.86
# Episode: 1016, Total Steps: 29908, Train_reward: 0.56, Eval_reward: 0.86
# Episode: 1017, Total Steps: 29947, Train_reward: 0.57, Eval_reward: 0.86
# Episode: 1018, Total Steps: 29985, Train_reward: 0.59, Eval_reward: 0.87
# Episode: 1019, Total Steps: 30031, Train_reward: 0.60, Eval_reward: 0.87
# --> reached_max_steps
# Mounted at /content/gdrive

# %% [markdown]
# ### 4. Plot the Reward

# %%
#dqn_steps1, dqn_r1, dqn_score1 = result1.T
dqn_steps2, dqn_r2, dqn_score2 = resultd2.T
#dqn_steps3, dqn_r3, dqn_score3 = result3.T

fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
plt.plot(dqn_score2, linewidth=2, label='Seed 10')
plt.ylabel('Rewards')
plt.xlabel('Episodes #')
leg = plt.legend();
ax1.set_title('Evaluation Reward Episodes')


fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
#plt.plot(dqn_steps1, dqn_score1, label='Seed 8')
plt.plot(dqn_steps2, dqn_score2, label='Seed 10')
#plt.plot(dqn_steps3, dqn_score3, label='Seed 12')
plt.ylabel('Reward')
plt.xlabel('Steps #')
leg = plt.legend();
ax2.set_title('Evaluation Reward')

# fig3 = plt.figure()
# ax3 = fig3.add_subplot(111)
# plt.plot(dqn_steps, linewidth=2)
# plt.ylabel('Steps')
# plt.xlabel('Episode #')
# ax3.set_title('Total Steps')


plt.show()

# %% [markdown]
# ### 5. Test the Policy!

# %%
display = Display(visible=0, size=(600, 400))
display.start()

def show_video(path):
    html = []
    for mp4 in Path(path).glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append('''<video alt="{}" autoplay
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>'''.format(mp4, video_b64.decode('ascii')))
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %%
env = gym.make('frogger-v1')
env = Monitor(env, './video', force=True, video_callable=lambda episode: True)
state = env.reset()
done = False
rev = 0
while not done:
    action = agentd2.greedy_action(state)
    state, reward, done, _ = env.step(action)
    rev += reward
print(rev)
env.close()
show_video('./video')

del env
# Out:
# Origin:  [0.0, 0.0]
# world_width:  50.0
# world_height:  50.0
# Screen:  <Surface(600x600x32 SW)>
# 1.2177725662015637
# <video alt="video/openaigym.video.1.73.video000000.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
